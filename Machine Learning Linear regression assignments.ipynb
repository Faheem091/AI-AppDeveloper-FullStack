# %% [markdown]
# ## BEST FIT LINE - Calling SKlearn linear regression
# ### Ex 1. Data:
# #### 1. Download the MPG data file from UCI Machine Learning repository https://archive.ics.uci.edu/ml/machine-learningdatabases/auto-mpg/
# #### 2. Identify target variable and independent variable.
# #### 3. Prepare the data file

# %% [markdown]
# Dataset Auto_MPG has been downloaded and we have identified MPG as a dependent variable and rest all are dependent variables.

# %% [markdown]
# ## Univariate Regression

# %%
# Ex 2. Import relevant python libraries and sklearn linear_model 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

import matplotlib.pyplot as plt

# %%
data_ml = pd.read_excel('d://auto-mpg.xlsx')
data_ml
# Out:
#       MPG  Cylinders  Displacement Horsepower  Weight  Acceleration  \
# 0     8.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      Model_year  Origin                   Car_Name
# 0          2015       1  chevrolet chevelle malibu
# ...

# %%
# Dropping categorical feature
data_ml.drop(['Car_Name'],axis=1,inplace=True)
data_ml.head()
# Out:
#     MPG  Cylinders  Displacement Horsepower  Weight  Acceleration  Model_year  \
# 0   8.0          8         307.0        130    3504          12.0        2015
# 1  15.0          8         350.0        165    3693          11.5        2015
# 2  18.0          8         318.0        150    3436          11.0        2015
# 3  16.0          8         304.0        150    3433          12.0        2015
# 4  17.0          8         302.0        140    3449          10.5        2015
#
#    Origin
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
data_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MPG           398 non-null    float64
#  1   Cylinders     398 non-null    int64
#  2   Displacement  398 non-null    float64
#  3   Horsepower    398 non-null    object
#  4   Weight        398 non-null    int64
#  5   Acceleration  398 non-null    float64
#  6   Model_year    398 non-null    int64
#  7   Origin        398 non-null    int64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 25.0+ KB

# %%
data_ml['Horsepower'].unique()
# Out:
# array([130, 165, 150, 140, 198, 220, 215, 225, 190, 170, 160, 95, 97, 85,
#        88, 46, 87, 90, 113, 200, 210, 193, '?', 100, 105, 175, 153, 180,
#        110, 72, 86, 70, 76, 65, 69, 60, 80, 54, 208, 155, 112, 92, 145,
#        137, 158, 167, 94, 107, 230, 49, 75, 91, 122, 67, 83, 78, 52, 61,
#        93, 148, 129, 96, 71, 98, 115, 53, 81, 79, 120, 152, 102, 108, 68,
#        58, 149, 89, 63, 48, 66, 139, 103, 125, 133, 138, 135, 142, 77, 62,
#        132, 84, 64, 74, 116, 82], dtype=object)

# %%
# copying dataset for further analysis.

data1 = data_ml

# %%
data_ml = data_ml[data_ml['Horsepower'] != '?']

# %%
data_ml.shape
# Out:
# (392, 8)

# %%
data_ml.corr()['MPG'].sort_values()
# Out:
# Weight         -0.830645
# Displacement   -0.805134
# Cylinders      -0.779069
# Model_year     -0.583311
# Acceleration    0.425674
# Origin          0.565084
# MPG             1.000000
# Name: MPG, dtype: float64

# %%
# Filtering out the warnings

import warnings

warnings.filterwarnings('ignore')

# %%
plt.style.use('dark_background')

sns.countplot(data_ml.Cylinders,data=data_ml)

plt.show()

# %%
sns.countplot(data_ml['Model_year'],palette = "rainbow")
plt.show()

# %%
sns.countplot(data_ml.Origin,palette = "rainbow")
plt.show()


# region 1 has more vehicles as compared to the other two regions.

# %%
data_ml['Horsepower'] = pd.to_numeric(data_ml['Horsepower'])
sns.distplot(data_ml['Horsepower'])
plt.show()

# %%
## multivariate analysis
sns.boxplot(y='MPG',x='Cylinders',data=data_ml,palette = "rainbow")
plt.show()

# %%
sns.boxplot(y='MPG',x='Model_year',data=data_ml,palette = "rainbow")
plt.show()

# %%
plt.style.use('default')

plot = sns.lmplot('Horsepower','MPG',data=data_ml,hue='Origin',palette = "rainbow")
plt.show()

# %%
plot = sns.lmplot('Acceleration','MPG',data=data_ml,hue='Origin',palette = "rainbow")
plot.set(ylim = (0,50))
plt.show()

# %%
plot = sns.lmplot('Weight','MPG',data=data_ml,hue='Origin',palette = "rainbow")
plt.show()

# %%
plot = sns.lmplot('Displacement','MPG',data=data_ml,hue='Origin',palette = "rainbow")
plot.set(ylim = (0,50))
plt.show()

# %% [markdown]
# ### Modelling

# %%
# Splitting the dataset into training and test set.
x = data_ml.iloc[:,1:].values
y = data_ml.iloc[:,0].values
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)
print(regressor.score(x_test,y_test))
# Out:
# 0.8359203736023628

# %%
regressor.intercept_
# Out:
# 1556.0836436229836

# %%
regressor.coef_
# Out:
# array([-0.48050864,  0.01774172, -0.00752176, -0.00674434,  0.16104104,
#        -0.75508406,  1.13404943])

# %%
a = pd.DataFrame({"Real" : y_test.reshape(-1), "Predicted":y_pred.reshape(-1)})
a.head(10)
# Out:
#    Real  Predicted
# 0  28.0  25.857620
# 1  22.3  25.713840
# 2  12.0  10.516823
# 3  38.0  32.286887
# 4  33.8  33.269346
# 5  19.4  23.440641
# 6  38.1  34.502645
# 7  30.0  26.164104
# 8  20.0  20.395138
# 9  20.0  27.083101

# %%
print("training", regressor.score(x_train, y_train))
print("testing", regressor.score(x_test, y_test))
print("Accuracy", r2_score(y_test, y_pred))
# Out:
# training 0.816639048270188
# testing 0.8359203736023628
# Accuracy 0.8359203736023628

# %%
plt.scatter(y_test, y_pred)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
datax=[]
datay=[]
def gradient(b_current,m_current,learningRate):
    bgradient=0
    mgradient=0
    N=float(len(datax))
    for i in range(0,len(datax)):
        bgradient+= (-2/N)*(datay[i]-((m_current*datax[i])+b_current))
        mgradient+= (-2/N)*datax[i]*(datay[i]-((m_current*datax[i])+b_current))
    newb=b_current-(bgradient*learningRate)
    newm=m_current-(mgradient*learningRate)
    return newm,newb
def basic_linear_regression(x, y):
    # Basic computations to save a little time.
    length = len(x)
    sum_x = sum(x)
    sum_y = sum(y)

    # sigma x^2, and sigma xy respectively.
    sum_x_squared = sum(map(lambda a: a * a, x))
    sum_of_products = sum([x[i] * y[i] for i in range(length)])

    # Magic formulae!  
    a = (sum_of_products - (sum_x * sum_y) / length) / (sum_x_squared - ((sum_x ** 2) / length))
    b = (sum_y - a * sum_x) / length
    return a, b

def error(m,b,datax,datay):
    error=0
    for i in range(0,len(datax)):
        error+=(datay[i]-(m*datax[i]+b))
    return error/len(datax)

# %%
datax=[]
datay=[]
def gradient(b_current,m_current,learningRate):
    bgradient=0
    mgradient=0
    N=float(len(datax))
    for i in range(0,len(datax)):
        bgradient+= (-2/N)*(datay[i]-((m_current*datax[i])+b_current))
        mgradient+= (-2/N)*datax[i]*(datay[i]-((m_current*datax[i])+b_current))
    newb=b_current-(bgradient*learningRate)
    newm=m_current-(mgradient*learningRate)
    return newm,newb
def basic_linear_regression(x, y):
    # Basic computations to save a little time.
    length = len(x)
    sum_x = sum(x)
    sum_y = sum(y)

    # sigma x^2, and sigma xy respectively.
    sum_x_squared = sum(map(lambda a: a * a, x))
    sum_of_products = sum([x[i] * y[i] for i in range(length)])

    # Magic formulae!  
    a = (sum_of_products - (sum_x * sum_y) / length) / (sum_x_squared - ((sum_x ** 2) / length))
    b = (sum_y - a * sum_x) / length
    return a, b

def error(m,b,datax,datay):
    error=0
    for i in range(0,len(datax)):
        error+=(datay[i]-(m*datax[i]+b))
    return error/len(datax)
